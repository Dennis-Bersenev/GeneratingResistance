# %%
import scanpy as sc
import utils

# %%
adata = sc.read('./../data/MGH66_bacdrop.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 1692542 × 4628
#     obs: 'sample', 'replicate'

# %%
adata = utils.process_adata(adata, normalize_counts=True, logarithmize=True)
adata
# Out:
# AnnData object with n_obs × n_vars = 6922 × 1738
#     obs: 'sample', 'replicate', 'n_genes'
#     var: 'n_cells'
#     uns: 'log1p'

# %%
adata=utils.cluster_adata(adata, feature_space="X", neighbor_method="knn")
adata
# Out:
# AnnData object with n_obs × n_vars = 6922 × 1738
#     obs: 'sample', 'replicate', 'n_genes', 'leiden'
#     var: 'n_cells'
#     uns: 'log1p', 'neighbors', 'leiden', 'umap'
#     obsm: 'X_umap'
#     obsp: 'distances', 'connectivities'

# %%
sc.pl.umap(adata, color='leiden', title="coloured by cluster assignment")
# Out:
# /home/dennis/miniconda3/envs/compbioGPU/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata, color='sample', title="coloured by cluster assignment")
# Out:
# /home/dennis/miniconda3/envs/compbioGPU/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata, color='replicate', title="coloured by cluster assignment")
# Out:
# /home/dennis/miniconda3/envs/compbioGPU/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
