# %%
import scanpy as sc

# %%
adata_z_g = sc.read('./../data/dge_analysis_inputs/adata_z_gauss.h5ad')
adata_u_g = sc.read('./../data/dge_analysis_inputs/adata_u_gauss.h5ad')
# adata_z_knn = sc.read('./../data/dge_analysis_inputs/adata_z_knn.h5ad')
# adata_u_knn = sc.read('./../data/dge_analysis_inputs/adata_u_knn.h5ad')

# %%
sc.pl.umap(adata_z_g, color='sample', title="coloured by sample")
# Out:
# /home/dennis/miniconda3/envs/compbioGPU/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata_u_g, color='sample', title="coloured by sample")
# Out:
# /home/dennis/miniconda3/envs/compbioGPU/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata_z_g, color='leiden', title="coloured by cluster assignment")
# Out:
# /home/dennis/miniconda3/envs/compbioGPU/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata_u_g, color='leiden', title="coloured by cluster assignment")
# Out:
# /home/dennis/miniconda3/envs/compbioGPU/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
